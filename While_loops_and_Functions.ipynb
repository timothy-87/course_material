# %% [markdown]
# <a href="https://colab.research.google.com/github/timothy-87/course_material/blob/main/While_loops_and_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #While loops
# While something is true, repeat your actions, e.g. when not facing a while, keep walking.

# %%
# Below is an example of a program that iterates through the use of a while loop
# We will start counting from 1, and then stop at 19
# (each time increasing the value of the count by 1)
#

# Defining where our loop will start counting from
increment_count = 1

# Performing our iteration by first defining when to perform the iteration
# in this case when the increment count is less than 20 and greater than 0
#
while 20 > increment_count > 0:
  print ('Increment = ', increment_count)
  increment_count = increment_count + 1
  a = increment_count

    # incrementing our increment_count by 1
print(a)
# Out:
# Increment =  1
# Increment =  2
# Increment =  3
# Increment =  4
# Increment =  5
# Increment =  6
# Increment =  7
# Increment =  8
# Increment =  9
# Increment =  10
# Increment =  11
# Increment =  12
# Increment =  13
# Increment =  14
# Increment =  15
# Increment =  16
# Increment =  17
# Increment =  18
# Increment =  19
# 20

# %%
# Example
# CHecking squares of numbers which between 0 and less than 10
x = 0
while x >= 0:


  x += 1

  if x==3:
    # print('x==3' )
    # continue
    pass

  if x == 20 :
   break
  print(x**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361

# %%
# Example
x = 1
n = 1000

while x < n:
  print(x)
  x *= 2


# What is the output? Why?
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %% [markdown]
# An infinite loop

# %%
while True:
  print('All work and no play makes Jack a dull boy')

# What is this output? Why?
# Out:
# Streaming output truncated to the last 5000 lines.
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# ...
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# All work and no play makes Jack a dull boy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6914c5da0649> in <module>
#       1 while True:
# ----> 2   print('All work and no play makes Jack a dull boy')
#       3
#       4 # What is this output? Why?
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# In this example we will work with nested while loops by creating while loop in
# a while loop.
#

# Creating an integer
n = 1

# Iterating whilst the value of n is less than or equal to 2
while n <= 2:

    # Creating an integer
    m = 1

    # Iterating whilst the value of m is less than or equal to 2
    while m <= 3:
        print('outer loop iteration {}, nested loop iteration {}'.format(n, m))

        # Adding 1 to value m
        m += 1

    # Adding 1 to value n
    n += 1
# Out:
# outer loop iteration 1, nested loop iteration 1
# outer loop iteration 1, nested loop iteration 2
# outer loop iteration 1, nested loop iteration 3
# outer loop iteration 2, nested loop iteration 1
# outer loop iteration 2, nested loop iteration 2
# outer loop iteration 2, nested loop iteration 3

# %%
# Quiz

# Print out the cuberoot of numbers between 1 and 10 inclusive using a while loop
#

# %%
# Quiz

# Using a nested loop, print “X is negative” as long as x is less than 0?

# %% [markdown]
# ### Break statement
#  The break statement allows you to exit a loop from any point within its body.

# %%
# Create a variable x = 0

x = 0

# Iterating whilst the value of x is less than 50
while x < 50:
  print(x)

# If x is 5, break loop
  if x ==4:
      print('x = 4')
  if x == 5:
    break

  x += 1 # Adding 1 to value n
# Out:
# 0
# 1
# 2
# 3
# 4
# x = 4
# 5

# %%
# Example
n = 1

while True:

    print (n)

    n+=1

    if n==4:

        break

print("Four!")
# Out:
# 1
# 2
# 3
# After Break

# %%
# Company  charges different bus ticket prices depending on a persons age.
# If a person is under the age of 3, the ticket is free;
# If they are between 3 and 12, the ticket is Ksh.500;
# and if they are over age 12, the ticket is Ksh.800.
# Write a loop in which you ask their age, and then tell them the cost of the ticket.
#

prompt = "\nPlease enter your age so we can tell you the price of the ticket:"
prompt += "\n(Enter 'done' when you are finished.) "

while True:
    age = input(prompt)
    if age == 'done':
        break
    age = int(age)


    if age < 3:
        print("Since you are " + str(age) + " the bus ticket is Free!")
    elif age > 3 and age <= 12:
        print("Since you are " + str(age) + " the bus ticket is Ksh.500.")
    else:
        print("Since you are " + str(age) + " the cost of the movie ticket is Ksh.800")
# Out:
# Please enter your age so we can tell you the price of the ticket:
# (Enter 'done' when you are finished.) 76
# Since you are 76 the cost of the movie ticket is Ksh.800
#
# Please enter your age so we can tell you the price of the ticket:
# (Enter 'done' when you are finished.) done

# %%
# Quiz
# Iterate through the following names list and stop if the name is Kibe
#

names = ['William', 'Mutua', 'Pauline', 'Waemba', 'Kibe', 'Lumumba']

# %%
# Quiz
# Write a program that finds the sum of any two numbers entered by a user,
# If one of the numbers is a negative number then the program should stop,
# else it could compute and display the sum

# %% [markdown]
# ### Continue Statement
# The continue statement works like break but instead of forcing termination,
# it forces the next iteration of the loop to take place
#  and skipping the rest of the code.

# %%
# CReate list
towns = ['kapenguria','kenol','mvita','mbale','nakuru']

# Our loops begin counting from 0
i = 0

# determining the no. of elements in our list
no_of_towns = len(towns)

# defining our word variable
word = "nakuru"


# Performing our iteration, starting from 0 until i is not less than the no_of_facilitators
while i < no_of_towns:

    print("Checking element:", i)

    if word != towns[i]:

        i = i + 1

        continue

    print("Find the element at ", i)

    # stop the loop
    i = no_of_towns
# Out:
# Checking element: 0
# Checking element: 1
# Checking element: 2
# Checking element: 3
# Checking element: 4
# Find the element at  4

# %%
# Asking the user for input and printing the input if is isn't #.
# if the input is #, we continue else if the input is 'done' we end the loop
#

print("Type 'done' when you want to leave the loop.")

while True:
    name = input('Please enter your name: ')
    if name == '#':

        continue

    if name == 'done':

        break

    print(name)


print('Done!')
# Out:
# Type 'done' when you want to leave the loop.
# Please enter your name: la
# la
# Please enter your name: done
# Done!

# %%
#  Let's while loop that prints out the following color list.
# If should skip the color green during iteration.
#

color = ['red', 'yellow', 'green', 'white', 'purple', 'blue']
i=0

while i<len(color):
  print(color[i])
  i=i+1
  if color[i]=='green':
    continue
# Out:
# red
# yellow
# green
# white
# purple
# blue
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-a7ea97ec0f23> in <module>
#       9   print(color[i])
#      10   i=i+1
# ---> 11   if color[i]=='green':
#      12     continue
#
# IndexError: list index out of range

# %% [markdown]
# ### Else Statement

# %%
# Another example of using an else and a break statement in a while loop
#

myNum = 6

myVar = 1

while myVar <= 10 :
    if myVar == myNum :
            print("Breaking out of the loop")
            break

    print("This number = " + str(myVar))
    myVar += 1

else:
    print("Break statement is executed, printing 'else' block")
# Out:
# This number = 1
# This number = 2
# This number = 3
# This number = 4
# This number = 5
# Breaking out of the loop

# %%
# Else statement
# Defining our start count
start = 0
while start < 3:

    print("Iterating inside while loop")

    start = start + 1

# The else statement will run if the while condition becomes false
else:
    print("Running the else block")
# Out:
# Iterating inside while loop
# Iterating inside while loop
# Iterating inside while loop
# Running the else block

# %%
# Find the minimum, maximum and average of a sequence of numbers

count = 0 # Number of non-negative numbers input
total = 0 # Sum of the non-negative numbers input

# Obtain numbers and determine count, min and max

print('Enter -1 to terminate entering numbers')

num =eval(input('Enter non negative number: '))

min = num
max = num

while num != -1:
  count += 1
  total += num

  # Introduce conditional statements
  if num < min:
    min = num
  if num > max:
    max = num
  num = eval(input('Enter non negative number: '))

if count > 0:
  print
  print('Min:',min)
  print('Max:',max)
  print('Average', total/count)

else:
  print("No nonnegative numbers were created")
# Out:
# Enter -1 to terminate entering numbers
# Enter non negative number: 0
# Enter non negative number: -1
# Min: 0
# Max: 0
# Average 0.0

# %%
# Quiz

# Write a program that takes in tempearature from a user,
# checks whether the unga prices is greater 150,
# then prints out whether the templerature is too hot or cold.
#

# %%
# Quiz
# Let's a program that takes a number between 0 - 100 as input.
# If we enter a valid number 3 times, then the while loop runs successfully,
# and the message from the else clause would get displayed i.e. "While loop ended!".
# If we enter an invalid number, then the loop would get aborted
# without execting the code in the else.
#

# %% [markdown]
# # Functions
# You can define functions to provide the required functionality. Here are simple rules to define a function in Python.
#
# - Function blocks begin with the keyword def followed by the function name and parentheses ( ( ) ).
#
# - Any input parameters or arguments should be placed within these parentheses. You can also define parameters inside these parentheses.
#
# - The first statement of a function can be an optional statement - the documentation string of the function or docstring.
#
# - The code block within every function starts with a colon (:) and is indented.
#
# - The statement return [expression] exits a function, optionally passing back an expression to the caller. A return statement with no arguments is the same as return None

# %%
# The syntax of a function
def functionname( parameters ):
   "function_docstring"
   function_suite
   return [expression]

# %%
def sumo():
  x = 5
  y = 8
  z = x*y
  return z

sumo()
# Out:
# 40

# %%
def printme(str):
  #  "This prints a passed string into this function"
   print(str)
   return




printme(9)
# Out:
# 9

# %% [markdown]
# ## Calling a Function
# Defining a function only gives it a name, specifies the parameters that are to be included in the function and structures the blocks of code.
#
# Once the basic structure of a function is finalized, you can execute it by calling it from another function or directly from the Python prompt.

# %%
# Function definition is here
def printme( str ):
  #  "This prints a passed string into this function"
   print(str)
   return;

# Now you can call printme function
printme("I'm first call to user defined function!")
printme("Again second call to the same function")
# Out:
# I'm first call to user defined function!
# Again second call to the same function

# %%
# A simple Python function defined by using the def keyword
def fun():
  print('welcome to coding functions')

# After creating a function, we call it by using the name of the function followed
# by parenthesis containing parameters of that particular function

fun()
# Out:
# welcome to coding functions

# %% [markdown]
# ##Arguments
# Information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %% [markdown]
# ### Default arguments
# A default argument is a parameter that assumes a default value if a value is not provided in the function call for that argument.

# %%
# Create function
def my_function(fname):
  print(fname + " Mwangi")


# Print full names
my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Mwangi
# Tobias Mwangi
# Linus Mwangi
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-89fdc1e81742> in <module>
#       7 my_function("Emil")
#       8 my_function("Tobias")
# ----> 9 my_function("Linus")()
#
# TypeError: 'NoneType' object is not callable

# %%
# A simple Python function to check
# whether x is even or odd


def evenOdd(x):
    if (x % 2 == 0):
        print("even")
    else:
        print("odd")


# Driver code to call the function
evenOdd(2)
evenOdd(3)
# Out:
# even
# odd

# %%
def  alphabet(letter):
  if letter in ('a','e','i','o','u'):
    print(letter, 'is a vowel')

  else:
    print(letter, 'is a consonant')

alphabet('t')
# Out:
# t is a consonant

# %% [markdown]
# Arguments are often shortened to args in Python documentations.
#
# From a function's perspective:
#
# - A parameter is the variable listed inside the parentheses in the function definition.
#
# - An argument is the value that is sent to the function when it is called.

# %% [markdown]
# ###**Number of arguments**
#
# By default, a function must be called with the correct number of arguments. Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less.

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil", "Refsnes")
my_function('job','Mcginn')
# If you try to call a function with 1 or 3arguments, you will get an error
# Out:
# Emil Refsnes
# job Mcginn

# %%
# This function expects two arguments but gets only 1
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil")
# Out:
# Emil Emil

# %%
# Python program to demonstrate
# default arguments


def myFun(x, y=50):
    print("x: ", x)
    print("y: ", y)


# Driver code (We call myFun() with only
# argument)
myFun(10)
# Out:
# x:  10
# y:  50

# %% [markdown]
# ### **Arbitrary Arguments,** *args
#
# If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#
# This way the function will receive a tuple of arguments, and can access the items accordingly

# %%
def my_function(*kids):
  print("The youngest child is " + kids[2])

# calling a function kids by the element of index 2 (3rd item)
my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %%
# Python program to illustrate
# *args for variable number of arguments


def myFun(*arguments):
    for arg in arguments:
        print(arg)


myFun('Hello,', 'Welcome', 'to', 'Bounty','Analytica')
# Out:
# Hello,
# Welcome
# to
# Bounty
# Analytica

# %% [markdown]
# ### **Keyword Arguments**
#
# You can also send arguments with the key = value syntax.
#
# This way the order of the arguments does not matter. The idea is to allow the caller to specify the argument name with values so that caller does not need to remember the order of parameters.

# %%
def my_function(child3, child2, child1):
  print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")
# Out:
# The youngest child is Linus

# %%
# Python program to demonstrate Keyword Arguments
def student(firstname, lastname):
    print(firstname, lastname)


# Keyword arguments
student(firstname='Ben', lastname='Kikok')
student(lastname='Kikok', firstname='Ben')

# Note that order of parameters does not matter
# Out:
# Ben Kikok
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-8452e97d7021> in <module>
#       6 # Keyword arguments
#       7 student(firstname='Ben', lastname='Kikok')
# ----> 8 student(lastname='Kikok', firstname='Ben',midname ='gitau')
#       9
#      10 # Note that order of parameters does not matter
#
# TypeError: student() got an unexpected keyword argument 'midname'

# %% [markdown]
# ### **Arbitrary Keyword Arguments**, **kwargs
#
# If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.
#
# This way the function will receive a dictionary of arguments, and can access the items accordingly:

# %%
# Python program to illustrate
# *kwargs for variable number of keyword arguments


def myFun(**kwargs):
    for key, value in kwargs.items():
        print("%s == %s" % (key, value))


# Driver code
myFun(first='Royco', mid='Mchuzi', last='Mix', flavour ='beef')
# Out:
# first == Royco
# mid == Mchuzi
# last == Mix
# flavour == beef

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %% [markdown]
# ### Default Parameter Value
#
# The following example shows how to use a default parameter value.
#
# If we call the function without argument, it uses the default value:

# %%
def my_function(country = "Norway"):
  print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %%
my_function('Kenya')
# Out:
# I am from Kenya

# %% [markdown]
# ### Passing a List as an Argument
# You can send any data types of argument to a function (string, number, list, dictionary etc.), and it will be treated as the same data type inside the function.
#
# E.g. if you send a List as an argument, it will still be a List when it reaches the function

# %%
def my_function(food):
  for x in food:
    print(x)

fruits = ["apple", "banana", "cherry"]

my_function(fruits)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Return Statement
#
# To let a function return a value, use the return statement
# The return statement can consist of a variable, an expression, or a constant which is returned to the end of the function execution.
# The statement return [expression] exits a function, optionally passing back an expression to the caller. A return statement with no arguments is the same as return None.

# %%
def my_function(x):
  return 5 * x

# Function returns multiple of x and 5
print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45

# %%
def square_value(num):
    # This function returns the square value of the entered number
    return num**2

square_value(2)
print(square_value(-4))
square_value(2)
# Out:
# 16
# 4

# %%
# Function definition is here
def sum( arg1, arg2 ):
   # Add both the parameters and return them."
   total = arg1 + arg2
   print("Inside the function : ", total)
   return total;

# Now you can call sum function
total = sum( 10, 20 );
print("Outside the function : ", total)
# Out:
# Inside the function :  30
# Outside the function :  30

# %% [markdown]
# ##**The pass Statement**
#
# function definitions cannot be empty, but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.

# %%
#  Uncomment the code to see what happens
def myfunction():
  # pass
# Out:
#   File "<ipython-input-60-bf0cb5f88e6e>", line 3
#     # pass
#           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## **Anonymous functions** in Python Function
# In Python, an anonymous function means that a function is without a name. As we already know the def keyword is used to define the normal functions and the lambda keyword is used to create anonymous functions.
#
# You can use the lambda keyword to create small anonymous functions.
#
# - Lambda forms can take any number of arguments but return just one value in the form of an expression. They cannot contain commands or multiple expressions.
#
# - An anonymous function cannot be a direct call to print because lambda requires an expression
#
# - Lambda functions have their own local namespace and cannot access variables other than those in their parameter list and those in the global namespace.

# %%
# Python code to illustrate the cube of a number
# using lambda function


def cube(x):
  return x*x*x

cube_v2 = lambda x : x*x*x

print(cube(7))
print(cube_v2(7))
# Out:
# 343

# %%
# An example of how lambda functions work

# Function definition is here
sum = lambda arg1, arg2: arg1 + arg2;

# Now you can call sum as a function
print("Value of total : ", sum( 10, 20 ))
print("Value of total : ", sum( 20, 20 ))
# Out:
# Value of total :  30
# Value of total :  40

# %% [markdown]
# ## Scope of Variables
# All variables in a program may not be accessible at all locations in that program. This depends on where you have declared a variable.
#
# The scope of a variable determines the portion of the program where you can access a particular identifier.
# Variables that are defined inside a function body have a local scope, and those defined outside have a global scope.
#
# This means that local variables can be accessed only inside the function in which they are declared, whereas global variables can be accessed throughout the program body by all functions. When you call a function, the variables declared inside it are brought into scope.

# %%
total = 0; # This is global variable.
# Function definition is here
def sum( arg1, arg2 ):
   # Add both the parameters and return them."
   total = arg1 + arg2; # Here total is local variable.
   print("Inside the function local total : ", total)
   return total;

# Now you can call sum function
sum( 10, 20 );
print("Outside the function global total : ", total )
# Out:
# Inside the function local total :  30
# Outside the function global total :  0

# %%
a = (lambda x: x*x*x)(10)
print(a)
# Out:
# 1000
